# %%
import numpy as np
from pylab import plot,show
n = 100
def mapa(r,x,n):
    if n==0:
        return x
    n -= 1
    return mapa(r,r*x*(1-x),n)

r1 = np.linspace(1,4,1000)
x1 = (r1 * 0) + 0.5

for i in range(n):
    x1 = mapa(r1,x1,1001)
    plot(r1,x1,'ko',ms=.1)
    


show()
