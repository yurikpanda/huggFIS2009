# %%
import numpy as np
from pylab import plot,loadtxt,imshow

data = loadtxt("stm.txt")
imshow(data,origin="lower",extent=[0,400,0,500],aspect=0.5)

# %%
import numpy as np
from pylab import plot,loadtxt,imshow,xlim,ylim

data = loadtxt("stm.txt")
xlim(300,600)
ylim(100,300)
imshow(data)

# %%
import numpy as np
from pylab import plot,loadtxt,imshow

data = loadtxt("stm.txt")
imshow(data)
