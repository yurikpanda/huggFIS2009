# %%
def catalan(n):
    c0=1
    for i in range(n+1):
        print (int(c0))
        c0 = ((4*i + 2)/(i + 2)) * c0
    return ('Hey')
catalan(4)
# Out:
# 1
# 1
# 2
# 5
# 14
# 'Hey'

# %%
from pylab import imshow,show,gray
from numpy import loadtxt

data = loadtxt("circular.txt",float)
imshow(data)
show()
